# %% [markdown]
# <a href="https://colab.research.google.com/github/haz05/TCC--Batuta_Eletronica/blob/main/Codigos/TCC_dados_v15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TCC- **BATUTA ELETRÔNICA PARA INCLUSÃO DE MÚSICOS COM DEFICIÊNCIA VISUAL EM ORQUESTRAS SINFÔNICAS**

# %% [markdown]
# Código 2
#
# Código para a criação e Conversão da Rede Neural para C++

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# Parte 1- Organização dos Dados em pares de Saídas e Entradas

# %%
from google.colab import files
import io

uploaded  = files.upload()
arquivo = next(iter(uploaded)) #importação do arquivo tratado no algoritimo TCC__dados_coleta
#f
#f = io.BytesIO(uploaded['teste-2.csv'])
# Out:
#      <input type="file" id="files-ca4d7387-61fc-45ac-9294-e5c1a4b147f7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ca4d7387-61fc-45ac-9294-e5c1a4b147f7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving df_dados.csv to df_dados.csv

# %%
import pandas as pd

gfile_name = io.StringIO(uploaded[arquivo].decode('ISO 8859-1').strip())
df = pd.read_csv(gfile_name)
df
# Out:
#        Unnamed: 0 sinal ()  aX ()  aY ()  aZ ()  gX ()  gY ()  gZ ()
# 0               0      OFF  -71.0 -488.0 -507.0 -108.0   25.0  -32.0
# 1               1      OFF  -60.0 -482.0 -516.0 -113.0   26.0  -33.0
# 2               2      OFF  -49.0 -478.0 -522.0 -118.0   28.0  -34.0
# 3               3      OFF  -38.0 -473.0 -526.0 -125.0   30.0  -34.0
# 4               4      OFF  -29.0 -468.0 -526.0 -131.0   32.0  -34.0
# ...           ...      ...    ...    ...    ...    ...    ...    ...
# 23546       23546      OFF   61.0 -275.0 -554.0 -209.0   80.0  -88.0
# 23547       23547      OFF   81.0 -257.0 -574.0 -219.0   86.0  -92.0
# 23548       23548      OFF  100.0 -237.0 -589.0 -230.0   93.0  -95.0
# 23549       23549      OFF  117.0 -215.0 -598.0 -240.0  100.0  -98.0
# 23550       23550      OFF  135.0 -190.0 -602.0 -250.0  108.0 -101.0
#
# [23551 rows x 8 columns]

# %%
# imporatação de bibliotecas para tratar os dados
# %matplotlib inline
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
print(df.columns.ravel())
# Out:
# ['Unnamed: 0' 'sinal ()' 'aX ()' 'aY ()' 'aZ ()' 'gX ()' 'gY ()' 'gZ ()']

# %%
df = df.drop('Unnamed: 0', 1)   #remove coluna desnecessária 
#df = df.drop('UNIX Timestamp (Milliseconds since 1970-01-01)', 1)
#df = df.loc[:,'aX ()':'sinal ()']
df
# Out:
#       sinal ()  aX ()  aY ()  aZ ()  gX ()  gY ()  gZ ()
# 0          OFF  -71.0 -488.0 -507.0 -108.0   25.0  -32.0
# 1          OFF  -60.0 -482.0 -516.0 -113.0   26.0  -33.0
# 2          OFF  -49.0 -478.0 -522.0 -118.0   28.0  -34.0
# 3          OFF  -38.0 -473.0 -526.0 -125.0   30.0  -34.0
# 4          OFF  -29.0 -468.0 -526.0 -131.0   32.0  -34.0
# ...        ...    ...    ...    ...    ...    ...    ...
# 23546      OFF   61.0 -275.0 -554.0 -209.0   80.0  -88.0
# 23547      OFF   81.0 -257.0 -574.0 -219.0   86.0  -92.0
# 23548      OFF  100.0 -237.0 -589.0 -230.0   93.0  -95.0
# 23549      OFF  117.0 -215.0 -598.0 -240.0  100.0  -98.0
# 23550      OFF  135.0 -190.0 -602.0 -250.0  108.0 -101.0
#
# [23551 rows x 7 columns]

# %%
df.reset_index(drop=True, inplace=True) #resetar o index da tabela
df
# Out:
#       sinal ()  aX ()  aY ()  aZ ()  gX ()  gY ()  gZ ()
# 0          OFF  -71.0 -488.0 -507.0 -108.0   25.0  -32.0
# 1          OFF  -60.0 -482.0 -516.0 -113.0   26.0  -33.0
# 2          OFF  -49.0 -478.0 -522.0 -118.0   28.0  -34.0
# 3          OFF  -38.0 -473.0 -526.0 -125.0   30.0  -34.0
# 4          OFF  -29.0 -468.0 -526.0 -131.0   32.0  -34.0
# ...        ...    ...    ...    ...    ...    ...    ...
# 23546      OFF   61.0 -275.0 -554.0 -209.0   80.0  -88.0
# 23547      OFF   81.0 -257.0 -574.0 -219.0   86.0  -92.0
# 23548      OFF  100.0 -237.0 -589.0 -230.0   93.0  -95.0
# 23549      OFF  117.0 -215.0 -598.0 -240.0  100.0  -98.0
# 23550      OFF  135.0 -190.0 -602.0 -250.0  108.0 -101.0
#
# [23551 rows x 7 columns]

# %%
#celula responsável por converter os dados para float e remover o ganho colocado para a transmissão do acelerometro ao emissor de dados, na fase de coleta de dados

df_temp1 = df.copy()   

df_temp1['aY ()'] = df_temp1['aY ()'].astype(float)
df_temp1['aY ()'] = pd.to_numeric(df_temp1['aY ()'], downcast='float')


df_temp1.loc[df_temp1['sinal ()'] == 'OFF', 'sinal ()'] = 0
df_temp1.loc[df_temp1['sinal ()'] == 'ON', 'sinal ()'] = 200

df_temp1['sinal ()'] = df_temp1['sinal ()'].astype(float)
df_temp1['sinal ()'] = pd.to_numeric(df_temp1['sinal ()'], downcast='float')

df_temp1['mag ()'] = 0

df_temp1['aX ()'] = df_temp1['aX ()']/100.0
df_temp1['aY ()'] = df_temp1['aY ()']/100.0
df_temp1['aZ ()'] = df_temp1['aZ ()']/100.0

# %%
#Laço responsável por criar o vetor magnitude 
for i in range(len(df_temp1)):

  
  a=  (df_temp1.iloc[i]['aX ()']**2) + (df_temp1.iloc[i]['aY ()']**2) + (df_temp1.iloc[i]['aZ ()']**2)

  #df_temp1.iloc[i]['mag ()'].values = 
  df_temp1['mag ()'].values[i] = a
  #print(df_temp1.iloc[i]['mag ()'])

# %%
#df_temp1['aY ()'] = df_temp1['aY ()']*60

# %%
#célula para visualização dos dados

plt.figure(figsize=(30,15))
df_temp1['aY ()'].plot()
df_temp1['sinal ()'].plot()
df_temp1['mag ()'].plot()
#df_temp1['aX ()'].plot()
#df_temp1['aZ ()'].plot()

plt.legend(fontsize=25)
plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlim([0,2000])
from google.colab import files
plt.savefig("alterado_mag.svg")
files.download("alterado_mag.svg")

# %%
#célula para remoção dos eixos para implementação da rede neural
df_temp1 = df_temp1.drop('aX ()', 1)
df_temp1 = df_temp1.drop('aY ()', 1)
df_temp1 = df_temp1.drop('aZ ()', 1)
df_temp1 = df_temp1.drop('gX ()', 1)
df_temp1 = df_temp1.drop('gY ()', 1)
df_temp1 = df_temp1.drop('gZ ()', 1)
#df_temp = df_temp.drop('predict', 1)
df_temp1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-52f5d441a2d2> in <module>()
# ----> 1 df_temp1 = df_temp1.drop('aX ()', 1)
#       2 df_temp1 = df_temp1.drop('aY ()', 1)
#       3 df_temp1 = df_temp1.drop('aZ ()', 1)
#       4 df_temp1 = df_temp1.drop('gX ()', 1)
#       5 df_temp1 = df_temp1.drop('gY ()', 1)
#
# NameError: name 'df_temp1' is not defined

# %%
#Célula para criação das matrizes de entradas e saídas correspondentes

#random_seed = 42   
n_time_steps = 5
n_features = 1 
step = 10 
#n_classes = 6 
n_epochs = 50       
n_batch_size = 100   
learning_rate = 0.0025
l2_loss = 0.0015

X_vet = []
Y_vet = []

import numpy as np

for i in range(0,  df_temp1.shape[0]- n_time_steps):  
  
  x_temp = df_temp1['mag ()'].values[i: i + n_time_steps]
  #y_temp = df_temp1['sinal ()'].values[i: i + n_time_steps]
  y_temp = df_temp1['sinal ()'].values[i: i + n_time_steps]/200

  X_vet.append(x_temp)
  Y_vet.append(y_temp)


X_vet = np.array(X_vet)
Y_vet = np.array(Y_vet)

#X = df_temp.loc[:,'aY ()']/800
#X = X.to_numpy()
#Y = df_temp.loc[:,'sinal ()']/1000
#Y = Y.to_numpy()

# %%
 #Transforma a dimenssão da matriz do eixo X para (n , 5, 1)
 reshaped_segments = np.asarray(X_vet, dtype= np.float32).reshape(-1, n_time_steps, n_features)
 #reshaped_segments

# %%
reshaped_segments.shape
# Out:
# (23546, 5, 1)

# %%
#Criação de um vetor com o par da saída
Y_final = []
for vetor in Y_vet:
  a = 0
  for i in vetor:
    if i > 0:
      a = 1
  Y_final.append(a)

# %%
Y_final =np.array(Y_final)
Y_final.shape
# Out:
# (23546,)

# %%
from tensorflow.keras.utils import to_categorical # utiliza a biblioteca do keras para formar uma matriz de pares binários
Yf = to_categorical(Y_final)

# %%
Yf.shape
# Out:
# (23546, 2)

# %%
from sklearn.model_selection import train_test_split # separação dos dados de treinamento e de teste
X_train, X_test, Y_train, Y_test = train_test_split(X_vet, Yf, test_size = 0.2)

# %%
Y_test[2][1]
# Out:
# 0.0

# %%
# for i in range(len(X_test)):
#   if Y_test[i][1] == 1:
#     print(X_test[i])

# %%
X_test
# Out:
# array([[ 33,  32,  32,  31,  30],
#        [466, 466, 462, 454, 443],
#        [ 49,  54,  59,  66,  73],
#        ...,
#        [ 26,  26,  27,  27,  28],
#        [ 37,  48,  60,  73,  86],
#        [ 90,  82,  74,  67,  60]])

# %%
# X = df_temp.loc[:,'aY ()']/800
# X = X.to_numpy()
# Y = df_temp.loc[:,'sinal ()']/1000
# Y = Y.to_numpy()
# X=X.reshape((-1, 1))
# X

# %%
# from operator import index
# import random
# import math

# # Aqui criamos uma lista de índices
# # embaralhados
# amostras = len(X)
# indexes = list(range(amostras))
# #random.shuffle(indexes)

# # Essa variável T indica quantas amostras
# # serão usadas para treinamento. As demais
# # serão usadas para validação
# T = math.floor(0.8*amostras)


# X_train = X[:T]
# Y_train = Y[:T]
# X_test = X[T:]
# Y_test = Y[T:]

# %%
Y_train.shape
# Out:
# (18836, 2)

# %% [markdown]
# Parte 2- Criação da Rede Neural

# %%
import numpy
import  tensorflow as tf 
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Bidirectional
from keras.layers import Dropout
from keras.layers import Embedding
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.engine.input_layer import Input
from keras.regularizers import l2
from keras.callbacks import ReduceLROnPlateau
from keras.layers import Reshape

# %%
#df

# %%
X_train.shape
# Out:
# (18836, 5)

# %% [markdown]
# Treinamento da Rede Neural

# %%
model = Sequential()
#model.add(Reshape((1,5), input_shape=(5,1)))

model.add(Dense(n_time_steps, activation='sigmoid',input_shape=(n_time_steps,)))
model.add(Dense(16, activation='sigmoid'))
#model.add(LSTM(units = 20, dropout=0.1, recurrent_dropout=0.1,input_shape=(5,1)))
#model.add(LSTM(10, dropout=0.1, recurrent_dropout=0.1))
model.add(Dropout(0.2))
model.add(Dense(2, activation='sigmoid')) 
class_weight = {0: 1.,
                  1: 1.}
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=opt,metrics='AUC')
history = model.fit(X_train, Y_train,class_weight =class_weight,validation_data=(X_test, Y_test), epochs=80, batch_size=60)
# Out:
# Epoch 1/80
# 314/314 [==============================] - 2s 3ms/step - loss: 0.4615 - auc: 0.8399 - val_loss: 0.4407 - val_auc: 0.8541
# Epoch 2/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.4453 - auc: 0.8499 - val_loss: 0.4325 - val_auc: 0.9071
# Epoch 3/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.4320 - auc: 0.8692 - val_loss: 0.4248 - val_auc: 0.8880
# Epoch 4/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.4182 - auc: 0.8862 - val_loss: 0.4006 - val_auc: 0.9271
# Epoch 5/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.3863 - auc: 0.9099 - val_loss: 0.3658 - val_auc: 0.9246
# Epoch 6/80
# 314/314 [==============================] - 1s 2ms/step - loss: 0.3483 - auc: 0.9261 - val_loss: 0.3231 - val_auc: 0.9407
# Epoch 7/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.3107 - auc: 0.9377 - val_loss: 0.2906 - val_auc: 0.9509
# Epoch 8/80
# 314/314 [==============================] - 1s 2ms/step - loss: 0.2791 - auc: 0.9462 - val_loss: 0.2584 - val_auc: 0.9599
# Epoch 9/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.2443 - auc: 0.9596 - val_loss: 0.2222 - val_auc: 0.9739
# Epoch 10/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.2067 - auc: 0.9739 - val_loss: 0.1998 - val_auc: 0.9823
# Epoch 11/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1822 - auc: 0.9803 - val_loss: 0.1752 - val_auc: 0.9847
# Epoch 12/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1760 - auc: 0.9811 - val_loss: 0.1667 - val_auc: 0.9839
# Epoch 13/80
# 314/314 [==============================] - 1s 2ms/step - loss: 0.1624 - auc: 0.9838 - val_loss: 0.1710 - val_auc: 0.9826
# Epoch 14/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1628 - auc: 0.9836 - val_loss: 0.1463 - val_auc: 0.9870
# Epoch 15/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1558 - auc: 0.9847 - val_loss: 0.1536 - val_auc: 0.9856
# Epoch 16/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1524 - auc: 0.9854 - val_loss: 0.1419 - val_auc: 0.9874
# Epoch 17/80
# 314/314 [==============================] - 1s 2ms/step - loss: 0.1520 - auc: 0.9853 - val_loss: 0.1410 - val_auc: 0.9873
# Epoch 18/80
# 314/314 [==============================] - 1s 2ms/step - loss: 0.1504 - auc: 0.9853 - val_loss: 0.1479 - val_auc: 0.9861
# Epoch 19/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1464 - auc: 0.9862 - val_loss: 0.1379 - val_auc: 0.9879
# Epoch 20/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1463 - auc: 0.9860 - val_loss: 0.1438 - val_auc: 0.9867
# Epoch 21/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1436 - auc: 0.9867 - val_loss: 0.1363 - val_auc: 0.9882
# Epoch 22/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1432 - auc: 0.9866 - val_loss: 0.1411 - val_auc: 0.9870
# Epoch 23/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1432 - auc: 0.9866 - val_loss: 0.1350 - val_auc: 0.9879
# Epoch 24/80
# 314/314 [==============================] - 1s 4ms/step - loss: 0.1454 - auc: 0.9863 - val_loss: 0.1338 - val_auc: 0.9887
# Epoch 25/80
# 314/314 [==============================] - 1s 4ms/step - loss: 0.1411 - auc: 0.9870 - val_loss: 0.1330 - val_auc: 0.9880
# Epoch 26/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1389 - auc: 0.9872 - val_loss: 0.1377 - val_auc: 0.9876
# Epoch 27/80
# 314/314 [==============================] - 1s 2ms/step - loss: 0.1396 - auc: 0.9870 - val_loss: 0.1426 - val_auc: 0.9872
# Epoch 28/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1356 - auc: 0.9877 - val_loss: 0.1367 - val_auc: 0.9878
# Epoch 29/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1370 - auc: 0.9873 - val_loss: 0.1291 - val_auc: 0.9891
# Epoch 30/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1345 - auc: 0.9876 - val_loss: 0.1333 - val_auc: 0.9887
# Epoch 31/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1373 - auc: 0.9873 - val_loss: 0.1535 - val_auc: 0.9873
# Epoch 32/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1329 - auc: 0.9880 - val_loss: 0.1385 - val_auc: 0.9888
# Epoch 33/80
# 314/314 [==============================] - 1s 2ms/step - loss: 0.1323 - auc: 0.9880 - val_loss: 0.1288 - val_auc: 0.9892
# Epoch 34/80
# 314/314 [==============================] - 1s 2ms/step - loss: 0.1310 - auc: 0.9881 - val_loss: 0.1441 - val_auc: 0.9866
# Epoch 35/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1327 - auc: 0.9878 - val_loss: 0.1284 - val_auc: 0.9892
# Epoch 36/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1284 - auc: 0.9886 - val_loss: 0.1396 - val_auc: 0.9888
# Epoch 37/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1289 - auc: 0.9888 - val_loss: 0.1301 - val_auc: 0.9893
# Epoch 38/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1300 - auc: 0.9885 - val_loss: 0.1275 - val_auc: 0.9889
# Epoch 39/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1309 - auc: 0.9884 - val_loss: 0.1454 - val_auc: 0.9883
# Epoch 40/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1312 - auc: 0.9881 - val_loss: 0.1314 - val_auc: 0.9904
# Epoch 41/80
# 314/314 [==============================] - 1s 2ms/step - loss: 0.1282 - auc: 0.9888 - val_loss: 0.1312 - val_auc: 0.9884
# Epoch 42/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1287 - auc: 0.9886 - val_loss: 0.1392 - val_auc: 0.9885
# Epoch 43/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1271 - auc: 0.9891 - val_loss: 0.1280 - val_auc: 0.9899
# Epoch 44/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1279 - auc: 0.9890 - val_loss: 0.1421 - val_auc: 0.9890
# Epoch 45/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1246 - auc: 0.9895 - val_loss: 0.1290 - val_auc: 0.9890
# Epoch 46/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1224 - auc: 0.9898 - val_loss: 0.1280 - val_auc: 0.9899
# Epoch 47/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1219 - auc: 0.9899 - val_loss: 0.1250 - val_auc: 0.9915
# Epoch 48/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1223 - auc: 0.9899 - val_loss: 0.1257 - val_auc: 0.9905
# Epoch 49/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1219 - auc: 0.9901 - val_loss: 0.1342 - val_auc: 0.9889
# Epoch 50/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1185 - auc: 0.9906 - val_loss: 0.1260 - val_auc: 0.9907
# Epoch 51/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1202 - auc: 0.9904 - val_loss: 0.1236 - val_auc: 0.9914
# Epoch 52/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1203 - auc: 0.9902 - val_loss: 0.1246 - val_auc: 0.9904
# Epoch 53/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1192 - auc: 0.9903 - val_loss: 0.1252 - val_auc: 0.9914
# Epoch 54/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1186 - auc: 0.9906 - val_loss: 0.1202 - val_auc: 0.9914
# Epoch 55/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1168 - auc: 0.9908 - val_loss: 0.1167 - val_auc: 0.9919
# Epoch 56/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1182 - auc: 0.9909 - val_loss: 0.1209 - val_auc: 0.9910
# Epoch 57/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1159 - auc: 0.9912 - val_loss: 0.1280 - val_auc: 0.9898
# Epoch 58/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1159 - auc: 0.9913 - val_loss: 0.1178 - val_auc: 0.9918
# Epoch 59/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1129 - auc: 0.9914 - val_loss: 0.1232 - val_auc: 0.9907
# Epoch 60/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1148 - auc: 0.9913 - val_loss: 0.1172 - val_auc: 0.9918
# Epoch 61/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1168 - auc: 0.9911 - val_loss: 0.1141 - val_auc: 0.9922
# Epoch 62/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1115 - auc: 0.9918 - val_loss: 0.1273 - val_auc: 0.9904
# Epoch 63/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1113 - auc: 0.9917 - val_loss: 0.1165 - val_auc: 0.9917
# Epoch 64/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1143 - auc: 0.9915 - val_loss: 0.1166 - val_auc: 0.9918
# Epoch 65/80
# 314/314 [==============================] - 1s 2ms/step - loss: 0.1168 - auc: 0.9912 - val_loss: 0.1124 - val_auc: 0.9922
# Epoch 66/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1203 - auc: 0.9902 - val_loss: 0.1325 - val_auc: 0.9889
# Epoch 67/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1137 - auc: 0.9913 - val_loss: 0.1130 - val_auc: 0.9924
# Epoch 68/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1148 - auc: 0.9912 - val_loss: 0.1115 - val_auc: 0.9927
# Epoch 69/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1136 - auc: 0.9913 - val_loss: 0.1143 - val_auc: 0.9919
# Epoch 70/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1106 - auc: 0.9917 - val_loss: 0.1364 - val_auc: 0.9891
# Epoch 71/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1107 - auc: 0.9917 - val_loss: 0.1118 - val_auc: 0.9927
# Epoch 72/80
# 314/314 [==============================] - 1s 2ms/step - loss: 0.1115 - auc: 0.9916 - val_loss: 0.1116 - val_auc: 0.9925
# Epoch 73/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1137 - auc: 0.9912 - val_loss: 0.1145 - val_auc: 0.9922
# Epoch 74/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1104 - auc: 0.9920 - val_loss: 0.1152 - val_auc: 0.9918
# Epoch 75/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1118 - auc: 0.9919 - val_loss: 0.1178 - val_auc: 0.9918
# Epoch 76/80
# 314/314 [==============================] - 1s 2ms/step - loss: 0.1080 - auc: 0.9921 - val_loss: 0.1085 - val_auc: 0.9928
# Epoch 77/80
# 314/314 [==============================] - 1s 2ms/step - loss: 0.1100 - auc: 0.9919 - val_loss: 0.1088 - val_auc: 0.9928
# Epoch 78/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1063 - auc: 0.9924 - val_loss: 0.1199 - val_auc: 0.9914
# Epoch 79/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1053 - auc: 0.9926 - val_loss: 0.1080 - val_auc: 0.9929
# Epoch 80/80
# 314/314 [==============================] - 1s 3ms/step - loss: 0.1099 - auc: 0.9922 - val_loss: 0.1131 - val_auc: 0.9921

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 5)                 30
#
#  dense_4 (Dense)             (None, 16)                96
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_5 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 160
# Trainable params: 160
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#plt.plot(np.array(history.history['loss']), "r--", label = "Train loss")
plt.plot(np.array(history.history['auc']), "g--", label = "Train AUC")
#plt.plot(np.array(history.history['val_loss']), "r-", label = "Validation loss")
plt.plot(np.array(history.history['val_auc']), "g-", label = "Validation auc")
plt.title("Training session's progress over iterations")
plt.legend(loc='lower left')
plt.ylabel('Training Progress (Loss/auc)')
plt.xlabel('Training Epoch')
plt.ylim(0) 
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, Y_test, batch_size = 60, verbose = 1)
print("Test Accuracy :", accuracy)
#print("Test Loss :", loss)
# Out:
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1131 - auc: 0.9921
# Test Accuracy : 0.9921356439590454

# %%
y = model.predict(X_vet)

# %%
#Verificação da rede neural

#model = get_model()
#y = model.predict(X_vet)
for i in range(X_vet.shape[0]):
  #for j in range(Y_test.shape[1]):
  print(Yf[i],y[i])

# %%
#Configura-se para valores acima de 0.45, uma predição correta

#y = model.predict(X_vet)
df_test = df_temp1.copy()
df_test['predict'] = 0.0
dados = np.zeros(len(df_test))
for i in range(len(df_test)-5):
  #print(i)
  if y[i,1] > 0.45:
    dados[i]= 100
  else:
    dados[i]= 0
df_test['predict']=pd.Series(dados)
  #print(dado)

# %%
#para que se possa observar, ajustou-se um ganho para o numero de validação  
df_test.loc[df_test['sinal ()'] == 0, 'sinal ()'] = 0
df_test.loc[df_test['sinal ()'] == 1, 'sinal ()'] = 100
#df_test['aY ()'] = df_temp1['aY ()']*1.5

# %%
#validação gráfica

plt.figure(figsize=(30,15))
df_test['mag ()'].plot()
df_test['sinal ()'].plot()
df_test['predict'].plot()
#df_test['aY ()'].plot()
plt.legend(fontsize=25)
plt.xticks(fontsize = 25)
plt.yticks(fontsize = 25)
plt.xlim([19000,23000])
plt.savefig("saida-rede-neural.svg")
files.download("saida-rede-neural.svg")

# %% [markdown]
# # A Rede Neural é convertida para C++ para que possa ser implemntada por Microcontroladores

# %%
pip install tinymlgen
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tinymlgen
#   Downloading tinymlgen-0.2.tar.gz (1.5 kB)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from tinymlgen) (2.8.2+zzzcolab20220527125636)
# Collecting hexdump
#   Downloading hexdump-3.3.zip (12 kB)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (2.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (1.1.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (3.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (1.46.3)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (0.5.3)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (1.21.6)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (14.0.1)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (2.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (4.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (57.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (3.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (1.14.1)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (0.26.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (0.2.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->tinymlgen) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow->tinymlgen) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow->tinymlgen) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (3.3.7)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (2.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (0.6.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->tinymlgen) (3.2.0)
# Building wheels for collected packages: tinymlgen, hexdump
#   Building wheel for tinymlgen (setup.py) ... done
#   Created wheel for tinymlgen: filename=tinymlgen-0.2-py3-none-any.whl size=2242 sha256=db44d7f9a1ecff093b3501b0fb7e908aed2268f9a19ceb6f8dc9906e1b176dd8
#   Stored in directory: /root/.cache/pip/wheels/1c/94/c7/a18049eea10532c9975ad7353fcccc7c436673285b4723a4bb
#   Building wheel for hexdump (setup.py) ... done
#   Created wheel for hexdump: filename=hexdump-3.3-py3-none-any.whl size=8913 sha256=bb3b2c5174ce8b2944362429eca460e8e59cb142171581be62da9c9982d5fba7
#   Stored in directory: /root/.cache/pip/wheels/68/fe/aa/06fd9d6968cfc3e1926eeab1ec728c246dafa120a72ff9afae
# Successfully built tinymlgen hexdump
# Installing collected packages: hexdump, tinymlgen
# Successfully installed hexdump-3.3 tinymlgen-0.2

# %%
#Ocorreram erros de utilização para a biblioteca, para contornar a situação, copiou-se a mesma e foi inserido codigos para a converesão adequada

import re
import hexdump

def port(model, optimize=False, variable_name='acel_model', pretty_print=False):
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.SELECT_TF_OPS]
    converter._experimental_lower_tensor_list_ops = False
    if optimize:
        if isinstance(optimize, bool):
            optimizers = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
        else:
            optimizers = optimize
        converter.optimizations = optimizers
    tflite_model = converter.convert()
    bytes = hexdump.dump(tflite_model).split(' ')
    c_array = ', '.join(['0x%02x' % int(byte, 16) for byte in bytes])
    c = 'const unsigned char %s[] DATA_ALIGN_ATTRIBUTE = {%s};' % (variable_name, c_array)
    if pretty_print:
        c = c.replace('{', '{\n\t').replace('}', '\n}')
        c = re.sub(r'(0x..?, ){12}', lambda x: '%s\n\t' % x.group(0), c)
    c += '\nconst int %s_len = %d;' % (variable_name, len(bytes))
    preamble = '''
// if having troubles with min/max, uncomment the following
// #undef min    
// #undef max
#ifdef __has_attribute
#define HAVE_ATTRIBUTE(x) __has_attribute(x)
#else
#define HAVE_ATTRIBUTE(x) 0
#endif
#if HAVE_ATTRIBUTE(aligned) || (defined(__GNUC__) && !defined(__clang__))
#define DATA_ALIGN_ATTRIBUTE __attribute__((aligned(4)))
#else
#define DATA_ALIGN_ATTRIBUTE
#endif
'''
    return preamble + c

# %%
#A celula a seguir gera o código necessário para se anexar ao código do Micro controlador

# #model = get_model()
# #from tinymlgen import port
c_code = port(model, pretty_print=True)
print(c_code)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp23odfj26/assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# // if having troubles with min/max, uncomment the following
# // #undef min
# // #undef max
# #ifdef __has_attribute
# #define HAVE_ATTRIBUTE(x) __has_attribute(x)
# #else
# #define HAVE_ATTRIBUTE(x) 0
# #endif
# #if HAVE_ATTRIBUTE(aligned) || (defined(__GNUC__) && !defined(__clang__))
# #define DATA_ALIGN_ATTRIBUTE __attribute__((aligned(4)))
# #else
# #define DATA_ALIGN_ATTRIBUTE
# #endif
# const unsigned char acel_model[] DATA_ALIGN_ATTRIBUTE = {
# 	0x1c, 0x00, 0x00, 0x00, 0x54, 0x46, 0x4c, 0x33, 0x14, 0x00, 0x20, 0x00,
# 	0x04, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x10, 0x00, 0x14, 0x00, 0x00, 0x00,
# 	0x18, 0x00, 0x1c, 0x00, 0x14, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
# 	0x18, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x38, 0x01, 0x00, 0x00,
# 	0x20, 0x00, 0x00, 0x00, 0xe0, 0x00, 0x00, 0x00, 0x58, 0x00, 0x00, 0x00,
# 	0x02, 0x00, 0x00, 0x00, 0xe4, 0x04, 0x00, 0x00, 0x2c, 0x04, 0x00, 0x00,
# 	0x01, 0x00, 0x00, 0x00, 0x3c, 0x01, 0x00, 0x00, 0x0f, 0x00, 0x00, 0x00,
# 	0x10, 0x0a, 0x00, 0x00, 0x0c, 0x0a, 0x00, 0x00, 0x40, 0x09, 0x00, 0x00,
# 	0xb0, 0x08, 0x00, 0x00, 0x58, 0x08, 0x00, 0x00, 0xa0, 0x07, 0x00, 0x00,
# 	0x0c, 0x06, 0x00, 0x00, 0x38, 0x05, 0x00, 0x00, 0xf0, 0x09, 0x00, 0x00,
# 	0xec, 0x09, 0x00, 0x00, 0xe8, 0x09, 0x00, 0x00, 0xe4, 0x09, 0x00, 0x00,
# 	0xe0, 0x09, 0x00, 0x00, 0xdc, 0x09, 0x00, 0x00, 0xbc, 0x00, 0x00, 0x00,
# 	0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0a, 0x00,
# 	0x10, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x04, 0x00, 0x0a, 0x00, 0x00, 0x00,
# 	0x0c, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00,
# 	0x0f, 0x00, 0x00, 0x00, 0x73, 0x65, 0x72, 0x76, 0x69, 0x6e, 0x67, 0x5f,
# 	0x64, 0x65, 0x66, 0x61, 0x75, 0x6c, 0x74, 0x00, 0x01, 0x00, 0x00, 0x00,
# 	0x14, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x24, 0x00, 0x00, 0x00,
# 	0x08, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x04, 0x00, 0x08, 0x00, 0x00, 0x00,
# 	0x0c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x07, 0x00, 0x00, 0x00,
# 	0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x35, 0x00, 0x62, 0xf7, 0xff, 0xff,
# 	0x04, 0x00, 0x00, 0x00, 0x0d, 0x00, 0x00, 0x00, 0x64, 0x65, 0x6e, 0x73,
# 	0x65, 0x5f, 0x33, 0x5f, 0x69, 0x6e, 0x70, 0x75, 0x74, 0x00, 0x00, 0x00,
# 	0x01, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x08, 0x00, 0x0c, 0x00,
# 	0x04, 0x00, 0x08, 0x00, 0x08, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
# 	0x0e, 0x00, 0x00, 0x00, 0x13, 0x00, 0x00, 0x00, 0x6d, 0x69, 0x6e, 0x5f,
# 	0x72, 0x75, 0x6e, 0x74, 0x69, 0x6d, 0x65, 0x5f, 0x76, 0x65, 0x72, 0x73,
# 	0x69, 0x6f, 0x6e, 0x00, 0xb2, 0xf7, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
# 	0x10, 0x00, 0x00, 0x00, 0x31, 0x2e, 0x31, 0x34, 0x2e, 0x30, 0x00, 0x00,
# 	0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0f, 0x00, 0x00, 0x00,
# 	0x4d, 0x4c, 0x49, 0x52, 0x20, 0x43, 0x6f, 0x6e, 0x76, 0x65, 0x72, 0x74,
# 	0x65, 0x64, 0x2e, 0x00, 0x00, 0x00, 0x0e, 0x00, 0x18, 0x00, 0x04, 0x00,
# 	0x08, 0x00, 0x0c, 0x00, 0x10, 0x00, 0x14, 0x00, 0x0e, 0x00, 0x00, 0x00,
# 	0x14, 0x00, 0x00, 0x00, 0x48, 0x00, 0x00, 0x00, 0x4c, 0x00, 0x00, 0x00,
# 	0x50, 0x00, 0x00, 0x00, 0x68, 0x00, 0x00, 0x00, 0x0d, 0x00, 0x00, 0x00,
# 	0x64, 0x08, 0x00, 0x00, 0x18, 0x08, 0x00, 0x00, 0xb0, 0x07, 0x00, 0x00,
# 	0x2c, 0x07, 0x00, 0x00, 0xc4, 0x06, 0x00, 0x00, 0x0c, 0x06, 0x00, 0x00,
# 	0x78, 0x04, 0x00, 0x00, 0x74, 0x03, 0x00, 0x00, 0xbc, 0x02, 0x00, 0x00,
# 	0x08, 0x02, 0x00, 0x00, 0x7c, 0x01, 0x00, 0x00, 0xe4, 0x00, 0x00, 0x00,
# 	0x5c, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
# 	0x01, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x06, 0x00, 0x00, 0x00,
# 	0xfc, 0x02, 0x00, 0x00, 0x60, 0x02, 0x00, 0x00, 0xac, 0x01, 0x00, 0x00,
# 	0x30, 0x01, 0x00, 0x00, 0x88, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
# 	0x04, 0x00, 0x00, 0x00, 0x6d, 0x61, 0x69, 0x6e, 0x00, 0x00, 0x00, 0x00,
# 	0xca, 0xfd, 0xff, 0xff, 0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
# 	0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00,
# 	0x01, 0x00, 0x00, 0x00, 0x0b, 0x00, 0x00, 0x00, 0x3c, 0xf8, 0xff, 0xff,
# 	0x14, 0x00, 0x00, 0x00, 0x0d, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00,
# 	0x40, 0x00, 0x00, 0x00, 0x30, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
# 	0x01, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x19, 0x00, 0x00, 0x00,
# 	0x53, 0x74, 0x61, 0x74, 0x65, 0x66, 0x75, 0x6c, 0x50, 0x61, 0x72, 0x74,
# 	0x69, 0x74, 0x69, 0x6f, 0x6e, 0x65, 0x64, 0x43, 0x61, 0x6c, 0x6c, 0x3a,
# 	0x30, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff,
# 	0x02, 0x00, 0x00, 0x00, 0x20, 0xf8, 0xff, 0xff, 0xaa, 0xfd, 0xff, 0xff,
# 	0x00, 0x00, 0x00, 0x08, 0x18, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00,
# 	0x04, 0x00, 0x00, 0x00, 0x38, 0xf8, 0xff, 0xff, 0x01, 0x00, 0x00, 0x00,
# 	0x0b, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x0a, 0x00, 0x00, 0x00,
# 	0x06, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0xc0, 0xf8, 0xff, 0xff,
# 	0x14, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00,
# 	0x60, 0x00, 0x00, 0x00, 0x50, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
# 	0x01, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x38, 0x00, 0x00, 0x00,
# 	0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31,
# 	0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x35, 0x2f, 0x4d, 0x61, 0x74,
# 	0x4d, 0x75, 0x6c, 0x3b, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
# 	0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x35,
# 	0x2f, 0x42, 0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x00, 0x00, 0x00, 0x00,
# 	0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff, 0x02, 0x00, 0x00, 0x00,
# 	0xc4, 0xf8, 0xff, 0xff, 0xe2, 0xfe, 0xff, 0xff, 0x01, 0x00, 0x00, 0x00,
# 	0x10, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
# 	0x0a, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x09, 0x00, 0x00, 0x00,
# 	0x54, 0xf9, 0xff, 0xff, 0x14, 0x00, 0x00, 0x00, 0x0b, 0x00, 0x00, 0x00,
# 	0x18, 0x00, 0x00, 0x00, 0x44, 0x00, 0x00, 0x00, 0x34, 0x00, 0x00, 0x00,
# 	0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
# 	0x1c, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
# 	0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x34,
# 	0x2f, 0x53, 0x69, 0x67, 0x6d, 0x6f, 0x69, 0x64, 0x00, 0x00, 0x00, 0x00,
# 	0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff, 0x10, 0x00, 0x00, 0x00,
# 	0x3c, 0xf9, 0xff, 0xff, 0xc6, 0xfe, 0xff, 0xff, 0x00, 0x00, 0x00, 0x08,
# 	0x18, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
# 	0x54, 0xf9, 0xff, 0xff, 0x01, 0x00, 0x00, 0x00, 0x09, 0x00, 0x00, 0x00,
# 	0x03, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00,
# 	0x02, 0x00, 0x00, 0x00, 0xdc, 0xf9, 0xff, 0xff, 0x14, 0x00, 0x00, 0x00,
# 	0x0a, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00, 0x60, 0x00, 0x00, 0x00,
# 	0x50, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
# 	0x10, 0x00, 0x00, 0x00, 0x38, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75,
# 	0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e,
# 	0x73, 0x65, 0x5f, 0x34, 0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x3b,
# 	0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31,
# 	0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x34, 0x2f, 0x42, 0x69, 0x61,
# 	0x73, 0x41, 0x64, 0x64, 0x00, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
# 	0xff, 0xff, 0xff, 0xff, 0x10, 0x00, 0x00, 0x00, 0xb4, 0xfa, 0xff, 0xff,
# 	0x00, 0x00, 0x0a, 0x00, 0x10, 0x00, 0x04, 0x00, 0x08, 0x00, 0x0c, 0x00,
# 	0x0a, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
# 	0x04, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
# 	0x01, 0x00, 0x00, 0x00, 0x07, 0x00, 0x00, 0x00, 0x58, 0xff, 0xff, 0xff,
# 	0x0e, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0e, 0x01, 0x00, 0x00, 0x00,
# 	0x8c, 0xfa, 0xff, 0xff, 0x14, 0x00, 0x00, 0x00, 0x09, 0x00, 0x00, 0x00,
# 	0x18, 0x00, 0x00, 0x00, 0x44, 0x00, 0x00, 0x00, 0x34, 0x00, 0x00, 0x00,
# 	0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00,
# 	0x1c, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
# 	0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x33,
# 	0x2f, 0x53, 0x69, 0x67, 0x6d, 0x6f, 0x69, 0x64, 0x00, 0x00, 0x00, 0x00,
# 	0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff, 0x05, 0x00, 0x00, 0x00,
# 	0x48, 0xfb, 0xff, 0xff, 0x00, 0x00, 0x0e, 0x00, 0x14, 0x00, 0x00, 0x00,
# 	0x08, 0x00, 0x0c, 0x00, 0x07, 0x00, 0x10, 0x00, 0x0e, 0x00, 0x00, 0x00,
# 	0x00, 0x00, 0x00, 0x08, 0x18, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00,
# 	0x04, 0x00, 0x00, 0x00, 0x9c, 0xfa, 0xff, 0xff, 0x01, 0x00, 0x00, 0x00,
# 	0x07, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
# 	0x04, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x10, 0x00,
# 	0x0b, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x04, 0x00, 0x0c, 0x00, 0x00, 0x00,
# 	0x09, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09, 0x01, 0x00, 0x00, 0x00,
# 	0x40, 0xfb, 0xff, 0xff, 0x14, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
# 	0x18, 0x00, 0x00, 0x00, 0x60, 0x00, 0x00, 0x00, 0x50, 0x00, 0x00, 0x00,
# 	0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00,
# 	0x38, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
# 	0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x33,
# 	0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x3b, 0x73, 0x65, 0x71, 0x75,
# 	0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e,
# 	0x73, 0x65, 0x5f, 0x33, 0x2f, 0x42, 0x69, 0x61, 0x73, 0x41, 0x64, 0x64,
# 	0x00, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff,
# 	0x05, 0x00, 0x00, 0x00, 0x44, 0xfb, 0xff, 0xff, 0x12, 0xfc, 0xff, 0xff,
# 	0x04, 0x00, 0x00, 0x00, 0x80, 0x00, 0x00, 0x00, 0xdc, 0x1f, 0xb9, 0xbf,
# 	0x9d, 0x36, 0x55, 0x3f, 0xcd, 0x35, 0x41, 0x3f, 0x69, 0x3f, 0xb4, 0xbf,
# 	0x3a, 0x3c, 0x7e, 0x3f, 0x10, 0x7e, 0xae, 0xbf, 0x7b, 0xcd, 0x27, 0x3f,
# 	0x0a, 0xbf, 0x9f, 0xbf, 0x71, 0xa4, 0xa4, 0xbf, 0x10, 0xbf, 0x45, 0x3f,
# 	0x47, 0x74, 0xa4, 0xbf, 0x77, 0x4d, 0x85, 0x3f, 0x89, 0x92, 0x3e, 0x3f,
# 	0xf9, 0xb1, 0x62, 0x3f, 0xb4, 0xd8, 0x2e, 0x3f, 0xdd, 0x68, 0x3b, 0x3f,
# 	0x36, 0xab, 0xb6, 0x3f, 0xdf, 0xa5, 0x59, 0xbf, 0x1e, 0x5a, 0x43, 0xbf,
# 	0x30, 0x97, 0xb0, 0x3f, 0x0f, 0x9d, 0x80, 0xbf, 0x40, 0x64, 0xb0, 0x3f,
# 	0x74, 0xc2, 0x27, 0xbf, 0x19, 0x39, 0xa1, 0x3f, 0x31, 0x5e, 0xa6, 0x3f,
# 	0xcf, 0xe4, 0x42, 0xbf, 0xd0, 0xb6, 0xa4, 0x3f, 0x99, 0x88, 0x84, 0xbf,
# 	0xe1, 0x6d, 0x3f, 0xbf, 0xfc, 0x14, 0x62, 0xbf, 0x53, 0x27, 0x2c, 0xbf,
# 	0xf9, 0xb3, 0x38, 0xbf, 0x82, 0xfc, 0xff, 0xff, 0x10, 0x00, 0x00, 0x00,
# 	0x07, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00, 0x30, 0x00, 0x00, 0x00,
# 	0x02, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
# 	0x1b, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
# 	0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x35,
# 	0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x00, 0x14, 0xfc, 0xff, 0xff,
# 	0xe2, 0xfc, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0x40, 0x01, 0x00, 0x00,
# 	0xb6, 0xb6, 0x83, 0xbe, 0x07, 0x4d, 0x1a, 0xc1, 0xe3, 0xc6, 0x31, 0x3e,
# 	0x97, 0x14, 0xbe, 0xbf, 0xc7, 0x12, 0xcb, 0xbe, 0xa7, 0x6d, 0xac, 0xbf,
# 	0x20, 0x69, 0x5d, 0x40, 0x45, 0x8f, 0x90, 0xbf, 0xd2, 0xaf, 0xce, 0x3f,
# 	0xbc, 0x0f, 0x50, 0xbd, 0x7d, 0xcd, 0x9a, 0xbf, 0xad, 0xd1, 0x61, 0x40,
# 	0x22, 0xb1, 0x4f, 0xbf, 0x3b, 0x05, 0xb5, 0x3f, 0x92, 0x7f, 0x26, 0x3e,
# 	0xbc, 0x47, 0xe7, 0xbe, 0x73, 0x61, 0x03, 0xc1, 0x96, 0x22, 0xa7, 0xbe,
# 	0xa7, 0x2f, 0xc8, 0xbf, 0x78, 0x20, 0x97, 0x3e, 0xa6, 0x83, 0xda, 0xbf,
# 	0xfe, 0x52, 0x56, 0x40, 0xb7, 0x2a, 0x7e, 0xbf, 0x1a, 0xd9, 0xe1, 0x3f,
# 	0x8a, 0x10, 0xfc, 0x3b, 0xda, 0xc2, 0xc2, 0x3d, 0x04, 0x22, 0x08, 0xc1,
# 	0x49, 0x0e, 0xeb, 0xbe, 0x00, 0xd4, 0xdc, 0xbf, 0x20, 0x04, 0x69, 0xbe,
# 	0xf3, 0xd0, 0x84, 0xbf, 0xbe, 0xd2, 0x64, 0x40, 0xc0, 0x6e, 0x47, 0xbf,
# 	0xbf, 0x77, 0x9a, 0x3f, 0x0e, 0xed, 0x5d, 0x3e, 0x69, 0x58, 0x65, 0x3d,
# 	0x60, 0xb2, 0x0f, 0xc1, 0x94, 0x05, 0xe4, 0xbe, 0xd4, 0xca, 0xf9, 0xbf,
# 	0xbf, 0x75, 0xeb, 0xbe, 0x5f, 0xa4, 0xb6, 0xbe, 0xea, 0xe4, 0xd9, 0xc0,
# 	0x12, 0x8d, 0x0a, 0xbe, 0xd8, 0x97, 0x60, 0xc0, 0xa0, 0x88, 0x8e, 0x3e,
# 	0xef, 0x3c, 0xa7, 0xbf, 0x0f, 0xe4, 0x49, 0x40, 0xf1, 0xbd, 0x48, 0xbf,
# 	0x4c, 0xb5, 0xb0, 0x3f, 0xbe, 0x65, 0xd0, 0xbe, 0x7a, 0xcb, 0xc0, 0xbe,
# 	0xfc, 0xf5, 0xcd, 0xc0, 0x0b, 0x69, 0x2b, 0xbe, 0xec, 0xfe, 0x04, 0xc0,
# 	0x6e, 0xf2, 0x80, 0x3d, 0x94, 0xf7, 0xdd, 0xbf, 0xb7, 0xee, 0x40, 0x40,
# 	0x16, 0x40, 0x39, 0xbf, 0xb7, 0xd6, 0xe5, 0x3f, 0xc3, 0xdc, 0xb0, 0xbe,
# 	0x12, 0xbc, 0x8f, 0xbf, 0x87, 0xfb, 0x46, 0x40, 0xc3, 0x19, 0xae, 0xbf,
# 	0xb7, 0x3b, 0xd9, 0x3f, 0xc9, 0xbb, 0xd2, 0xbe, 0x59, 0x1b, 0xad, 0xbf,
# 	0xa9, 0x93, 0x53, 0x40, 0x82, 0x30, 0x73, 0xbf, 0xe3, 0x3a, 0xf1, 0x3f,
# 	0x08, 0xfd, 0x9a, 0xbe, 0x20, 0x8b, 0x65, 0xbf, 0x50, 0x21, 0x3d, 0x40,
# 	0xda, 0xe9, 0x66, 0xbf, 0x7b, 0x6a, 0xb6, 0x3f, 0x8d, 0xdc, 0xc0, 0x3e,
# 	0x78, 0x11, 0xa4, 0xbf, 0x21, 0xad, 0x44, 0x40, 0x19, 0xc4, 0x6d, 0xbf,
# 	0xe6, 0x7e, 0xc3, 0x3f, 0x7d, 0x9a, 0x29, 0x3e, 0x12, 0xfe, 0xff, 0xff,
# 	0x10, 0x00, 0x00, 0x00, 0x06, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00,
# 	0x30, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
# 	0x05, 0x00, 0x00, 0x00, 0x1b, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75,
# 	0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e,
# 	0x73, 0x65, 0x5f, 0x34, 0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x00,
# 	0xa4, 0xfd, 0xff, 0xff, 0x72, 0xfe, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
# 	0x64, 0x00, 0x00, 0x00, 0xd2, 0xaf, 0xae, 0x3e, 0xfc, 0x23, 0xe2, 0xbe,
# 	0x97, 0x36, 0x20, 0x3f, 0x39, 0xa1, 0x47, 0xbf, 0x62, 0x3a, 0x0c, 0x3f,
# 	0x22, 0xa6, 0xd1, 0xbe, 0x98, 0x2d, 0x2b, 0x3f, 0x15, 0x78, 0xa4, 0x3d,
# 	0x65, 0x7b, 0x02, 0xbf, 0x0a, 0x5d, 0x05, 0x3e, 0x75, 0xad, 0x90, 0x3e,
# 	0x14, 0x4a, 0xe1, 0xbe, 0x3e, 0x6d, 0x98, 0xbe, 0x34, 0xf5, 0x13, 0x3e,
# 	0x11, 0x37, 0x16, 0xbe, 0x39, 0x11, 0x26, 0x3f, 0x85, 0xa4, 0xbf, 0xbd,
# 	0xe7, 0xda, 0x45, 0x3d, 0x03, 0x43, 0x2a, 0xbf, 0x03, 0xf4, 0x84, 0xbc,
# 	0xd0, 0x69, 0xe6, 0xbe, 0xf2, 0x69, 0xc7, 0xbe, 0xc7, 0x53, 0xba, 0xbe,
# 	0x88, 0x23, 0x26, 0xbf, 0x0f, 0xe9, 0xb2, 0x3e, 0xc6, 0xfe, 0xff, 0xff,
# 	0x10, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00,
# 	0x30, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00,
# 	0x05, 0x00, 0x00, 0x00, 0x1b, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75,
# 	0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x5f, 0x31, 0x2f, 0x64, 0x65, 0x6e,
# 	0x73, 0x65, 0x5f, 0x33, 0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x00,
# 	0x58, 0xfe, 0xff, 0xff, 0x26, 0xff, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
# 	0x14, 0x00, 0x00, 0x00, 0x9c, 0x1d, 0x4b, 0xbf, 0xa9, 0x7e, 0x05, 0x41,
# 	0x2a, 0x42, 0x92, 0xbf, 0x8d, 0xc6, 0xa5, 0x40, 0xd6, 0xff, 0x60, 0xbd,
# 	0x2a, 0xff, 0xff, 0xff, 0x10, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
# 	0x10, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
# 	0x05, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x64, 0x65, 0x6e, 0x73,
# 	0x65, 0x5f, 0x33, 0x2f, 0x62, 0x69, 0x61, 0x73, 0x00, 0x00, 0x00, 0x00,
# 	0xac, 0xfe, 0xff, 0xff, 0x7a, 0xff, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
# 	0x40, 0x00, 0x00, 0x00, 0x8d, 0x17, 0x7f, 0xbe, 0xab, 0x54, 0xc8, 0xbf,
# 	0x66, 0x8d, 0xc4, 0xbf, 0xa8, 0xaf, 0xc1, 0xbd, 0x00, 0x95, 0xa3, 0xbf,
# 	0x5b, 0xbe, 0xd0, 0xbe, 0x0c, 0xd3, 0xc1, 0xbf, 0x36, 0x03, 0xd9, 0xbe,
# 	0x48, 0x20, 0xaa, 0xbe, 0x71, 0x62, 0x9e, 0xbf, 0xb5, 0xd6, 0x31, 0xbe,
# 	0xb1, 0xa2, 0xb4, 0xbf, 0xf9, 0x45, 0xc0, 0xbf, 0x64, 0x7a, 0xd7, 0xbf,
# 	0xba, 0xf7, 0xab, 0xbf, 0xda, 0x2e, 0xb3, 0xbf, 0xaa, 0xff, 0xff, 0xff,
# 	0x10, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
# 	0x24, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
# 	0x0c, 0x00, 0x00, 0x00, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x34, 0x2f,
# 	0x62, 0x69, 0x61, 0x73, 0x00, 0x00, 0x00, 0x00, 0x04, 0x00, 0x06, 0x00,
# 	0x04, 0x00, 0x00, 0x00, 0x00, 0x00, 0x06, 0x00, 0x08, 0x00, 0x04, 0x00,
# 	0x06, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
# 	0xab, 0xe9, 0x87, 0xbe, 0x0b, 0xdb, 0x87, 0x3e, 0x00, 0x00, 0x0e, 0x00,
# 	0x14, 0x00, 0x04, 0x00, 0x00, 0x00, 0x08, 0x00, 0x0c, 0x00, 0x10, 0x00,
# 	0x0e, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
# 	0x10, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
# 	0x02, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x64, 0x65, 0x6e, 0x73,
# 	0x65, 0x5f, 0x35, 0x2f, 0x62, 0x69, 0x61, 0x73, 0x00, 0x00, 0x00, 0x00,
# 	0x90, 0xff, 0xff, 0xff, 0x14, 0x00, 0x18, 0x00, 0x04, 0x00, 0x00, 0x00,
# 	0x08, 0x00, 0x0c, 0x00, 0x10, 0x00, 0x00, 0x00, 0x00, 0x00, 0x14, 0x00,
# 	0x14, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
# 	0x18, 0x00, 0x00, 0x00, 0x44, 0x00, 0x00, 0x00, 0x34, 0x00, 0x00, 0x00,
# 	0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00,
# 	0x1f, 0x00, 0x00, 0x00, 0x73, 0x65, 0x72, 0x76, 0x69, 0x6e, 0x67, 0x5f,
# 	0x64, 0x65, 0x66, 0x61, 0x75, 0x6c, 0x74, 0x5f, 0x64, 0x65, 0x6e, 0x73,
# 	0x65, 0x5f, 0x33, 0x5f, 0x69, 0x6e, 0x70, 0x75, 0x74, 0x3a, 0x30, 0x00,
# 	0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff, 0x05, 0x00, 0x00, 0x00,
# 	0xfc, 0xff, 0xff, 0xff, 0x04, 0x00, 0x04, 0x00, 0x04, 0x00, 0x00, 0x00
# };
# const int acel_model_len = 2664;
